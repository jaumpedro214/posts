# %% [markdown]
# ## DuckLake First Look

# %% [markdown]
# 💡 Instructions : Start the container with **Docker Compose** and connect to the Jupyter Server at `localhost:8888/lab`

# %%
import duckdb

# %% [markdown]
# Connect to the DuckDB Database

# %%
db = duckdb.connect('br_electorate.duckdb')
db.sql('USE electorate;')
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 db = duckdb.connect('br_electorate.duckdb', read_only=True)
#       2 db.sql('USE electorate;')
#
# IOException: IO Error: Could not set lock on file "/data/br_electorate.duckdb": Conflicting lock is held in /usr/local/bin/python3.10 (PID 1294). See also https://duckdb.org/docs/stable/connect/concurrency

# %%
db.sql('''
    SELECT
        *
    FROM current_electorate_per_state
''')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 db.sql('''
#       2     SELECT
#       3         *
#       4     FROM current_electorate_per_state
#       5 ''')
#
# NameError: name 'db' is not defined
